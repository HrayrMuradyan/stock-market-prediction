# %%
import json
from pathlib import Path
from datetime import datetime, timedelta
import yfinance as yf
import pandas as pd

# %%
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.append(parent_dir)

# %%
from src.utils.config import load_config
from src.data_extractor.tickers import get_most_recent_tickers_file

# %%
tickers_folder = "../metadata/tickers_list/"
config_path = "../configs/main.yaml"

# %%
config = load_config(config_path)
config.keys()
# Out:
# dict_keys(['metadata', 'stock'])

# %%
most_recent_tickers_file = get_most_recent_tickers_file(tickers_folder, config['metadata']['tickers_list_filename'])

# %%
with open(most_recent_tickers_file, "r") as f:
    tickers_list = json.load(f)

# %%
from src.utils.path import verify_saving_path, verify_existing_path
from src.data_extractor.stocks import update_stock_data, download_stock_data
import shutil

# %%
from datetime import datetime, timedelta
import yfinance as yf
from pathlib import Path
import pandas as pd
import sys
import os
from src.utils.path import verify_saving_path, verify_existing_path
import shutil
import numpy as np



        


def update_stock_data(data_folder, stock_data_start_date, keep_n_archived=3, column="Adj Close"):

    # Check the input
    verify_existing_path(data_folder)

    if not isinstance(stock_data_start_date, str):
        raise TypeError(f"Expected stock_data_start_date to be a string. Got {type(stock_data_start_date).__name__}.")

    if not isinstance(keep_n_archived, int):
        raise TypeError(f"Expected keep_n_archived to be an integer. Got {type(keep_n_archived).__name__}.")

    if not isinstance(column, str):
        raise TypeError(f"Expected column to be a string. Got {type(column).__name__}.")
    

    # Convert the data folder to Path object
    data_folder_path = Path(data_folder)

    # Get todays date
    todays_date = datetime.today().strftime("%Y-%m-%d")
    print(f"Todays date: {todays_date}")

    # List to store tickers for update
    tickers_to_update = []

    # For each ticker folder
    for ticker_index, ticker_folder in enumerate(data_folder_path.glob("*")):

        # --------------------- Get ticker and data information ----------------------- 

        # Get the ticker name from the folder
        ticker = ticker_folder.stem

        print(f"Processing ticker {ticker_index}: {ticker}")

        # Get sorted non-archived csv files
        all_ticker_csv_files = sorted(ticker_folder.glob(f"{ticker}_*.csv"))


        # --------------------- If the most recent file exists and it's date is todays date, skip. Else, add it to the update list -----------------------

        if (all_ticker_csv_files and all_ticker_csv_files[-1].stem.split("_")[-1] == todays_date):
            continue

        else:
            tickers_to_update.append(ticker)
            
    # If no stock data found to be update, quit the function
    if not tickers_to_update:
        return


    # --------------------- Update the tickers in the list -----------------------
    updated_stock_data = download_stock_data(ticker=tickers_to_update,
                               stock_data_start_date=stock_data_start_date,
                               stock_data_end_date=todays_date,
                               column=column) 

    # Remove any stocks that have missing data
    updated_stock_data = updated_stock_data.loc[:, updated_stock_data.isna().sum() == 0]

    # Save each ticker data separately
    for ticker in updated_stock_data.columns:

        # Define the folder for that specific ticker
        ticker_data_save_path = data_folder_path / ticker

        # Get sorted ticker csv files
        all_ticker_csv_files = sorted(ticker_data_save_path.glob(f"{ticker}_*.csv"))

        # Save the updated stock data
        updated_stock_data[[ticker]].to_csv(str(ticker_data_save_path / f"{ticker}_{todays_date}.csv"))

        # Delete the old stock data
        remove_file(all_ticker_csv_files[-1])


    # --------------------- Create or update archives -----------------------

    # Iterate over the updated data
    for ticker_index, ticker_folder in enumerate(data_folder_path.glob("*")):

        # Get all archived csv files and ticker data
        all_archive_csv_files = sorted(ticker_folder.glob(f"archive_*.csv"))
        all_ticker_csv_files = sorted(ticker_folder.glob(f"{ticker}_*.csv"))

        # Get the most recent csv file
        most_recent_ticker_file = all_ticker_csv_files[-1]

        # Get the ticker name from the folder
        ticker = ticker_folder.stem
            
        # If no archived files
        if not all_archive_csv_files:
            
            print("No archived files")
            
            # Define a new filename to archive the current most recent ticker file
            save_a_copy = most_recent_ticker_file.with_name("archive_" + most_recent_ticker_file.stem + most_recent_ticker_file.suffix)
            
            # Copy the most recent ticker file
            copy_file(most_recent_ticker_file, save_a_copy)
    
            # Append the new archive file to the all_archive_csv_files
            all_archive_csv_files.append(save_a_copy)

        else:
        
            # --------------------- Check if the most recent archived data was a week ago, create a new archive file ----------------------- 
            most_recent_archived_file = all_archive_csv_files[-1]
        
            # The date of the most recent archived file
            most_recent_archived_file_date = most_recent_archived_file.stem.split("_")[-1]
            most_recent_archived_date = datetime.strptime(most_recent_archived_file_date, "%Y-%m-%d").date()

            # Check if the most recent archived file date was a week ago, create a new archive file
            if datetime.today().date() >= most_recent_archived_date + timedelta(weeks=1):

                print("There is an archived file and it's date is a week before. Time to create a new one")
        
                # Define a new filename to archive the current most recent ticker file
                new_archive = most_recent_ticker_file.with_name("archive_" + most_recent_ticker_file.stem + most_recent_ticker_file.suffix)
                
                # Copy the most recent ticker file
                copy_file(most_recent_ticker_file, new_archive)

                # Add the new archive to the archive list
                all_archive_csv_files.append(new_archive)

            
            # --------------------- If there are more than "keep_n_archived" archived data files, remove oldest ones ----------------------- 
            
            # If there are more than "keep_n_archived" archived files, remove all
            n_archived_files = len(all_archive_csv_files)
            while n_archived_files > keep_n_archived:
        
                # Get the oldest archive file
                oldest_archive_file = all_archive_csv_files[0]
        
                # Remove the oldest archive file
                remove_file(oldest_archive_file)
        
                # Check the number of archived files again
                all_archive_csv_files = sorted(ticker_folder.glob(f"archive_*.csv"))
                n_archived_files = len(all_archive_csv_files)

# %%
update_stock_data("../data/", stock_data_start_date = "2010-01-01")
# Out:
# Todays date: 2025-07-24
# Processing ticker 0: A
# Processing ticker 1: AAPL
# Processing ticker 2: ABT
# Processing ticker 3: ACGL
# Processing ticker 4: ACN
# Processing ticker 5: ADBE
# Processing ticker 6: ADI
# Processing ticker 7: ADM
# Processing ticker 8: ADP
# Processing ticker 9: ADSK
# Processing ticker 10: AEE
# Processing ticker 11: AEP
# Processing ticker 12: AES
# Processing ticker 13: AFL
# Processing ticker 14: AIG
# Processing ticker 15: AIZ
# Processing ticker 16: AJG
# Processing ticker 17: AKAM
# Processing ticker 18: ALB
# Processing ticker 19: ALGN
# Processing ticker 20: ALL
# Processing ticker 21: AMAT
# Processing ticker 22: AMD
# Processing ticker 23: AME
# Processing ticker 24: AMGN
# Processing ticker 25: AMP
# Processing ticker 26: AMT
# Processing ticker 27: AMZN
# Processing ticker 28: AON
# Processing ticker 29: AOS
# Processing ticker 30: APA
# Processing ticker 31: APD
# Processing ticker 32: APH
# Processing ticker 33: ARE
# Processing ticker 34: ATO
# Processing ticker 35: AVB
# Processing ticker 36: AVGO
# Processing ticker 37: AVY
# Processing ticker 38: AWK
# Processing ticker 39: AXON
# Processing ticker 40: AXP
# Processing ticker 41: AZO
# Processing ticker 42: BA
# Processing ticker 43: BAC
# Processing ticker 44: BALL
# Processing ticker 45: BAX
# Processing ticker 46: BBY
# Processing ticker 47: BDX
# Processing ticker 48: BEN
# Processing ticker 49: BG
# Processing ticker 50: BIIB
# Processing ticker 51: BK
# Processing ticker 52: BKNG
# Processing ticker 53: BKR
# Processing ticker 54: BLDR
# Processing ticker 55: BLK
# Processing ticker 56: BMY
# Processing ticker 57: BR
# Processing ticker 58: BRO
# Processing ticker 59: BSX
# Processing ticker 60: BX
# Processing ticker 61: BXP
# Processing ticker 62: C
# Processing ticker 63: CAG
# Processing ticker 64: CAH
# Processing ticker 65: CAT
# Processing ticker 66: CB
# Processing ticker 67: CBRE
# Processing ticker 68: CCI
# Processing ticker 69: CCL
# Processing ticker 70: CDNS
# Processing ticker 71: CF
# Processing ticker 72: CHD
# Processing ticker 73: CHRW
# Processing ticker 74: CI
# Processing ticker 75: CINF
# Processing ticker 76: CL
# Processing ticker 77: CLX
# Processing ticker 78: CMCSA
# Processing ticker 79: CME
# Processing ticker 80: CMG
# Processing ticker 81: CMI
# Processing ticker 82: CMS
# Processing ticker 83: CNC
# Processing ticker 84: CNP
# Processing ticker 85: COF
# Processing ticker 86: COO
# Processing ticker 87: COP
# Processing ticker 88: COR
# Processing ticker 89: COST
# Processing ticker 90: CPB
# Processing ticker 91: CPRT
# Processing ticker 92: CPT
# Processing ticker 93: CRL
# Processing ticker 94: CRM
# Processing ticker 95: CSCO
# Processing ticker 96: CSGP
# Processing ticker 97: CSX
# Processing ticker 98: CTAS
# Processing ticker 99: CTRA
# Processing ticker 100: CTSH
# Processing ticker 101: CVS
# Processing ticker 102: CVX
# Processing ticker 103: D
# Processing ticker 104: DAL
# Processing ticker 105: DD
# Processing ticker 106: DE
# Processing ticker 107: DECK
# Processing ticker 108: DG
# Processing ticker 109: DGX
# Processing ticker 110: DHI
# Processing ticker 111: DHR
# Processing ticker 112: DIS
# Processing ticker 113: DLR
# Processing ticker 114: DLTR
# Processing ticker 115: DOC
# Processing ticker 116: DOV
# Processing ticker 117: DPZ
# Processing ticker 118: DRI
# Processing ticker 119: DTE
# Processing ticker 120: DUK
# Processing ticker 121: DVA
# Processing ticker 122: DVN
# Processing ticker 123: DXCM
# Processing ticker 124: EA
# Processing ticker 125: EBAY
# Processing ticker 126: ECL
# Processing ticker 127: ED
# Processing ticker 128: EFX
# Processing ticker 129: EG
# Processing ticker 130: EIX
# Processing ticker 131: EL
# Processing ticker 132: ELV
# Processing ticker 133: EMN
# Processing ticker 134: EMR
# Processing ticker 135: EOG
# Processing ticker 136: EQIX
# Processing ticker 137: EQR
# Processing ticker 138: EQT
# Processing ticker 139: ERIE
# Processing ticker 140: ES
# Processing ticker 141: ESS
# Processing ticker 142: ETN
# Processing ticker 143: ETR
# Processing ticker 144: EVRG
# Processing ticker 145: EW
# Processing ticker 146: EXC
# Processing ticker 147: EXPD
# Processing ticker 148: EXPE
# Processing ticker 149: EXR
# Processing ticker 150: F
# Processing ticker 151: FAST
# Processing ticker 152: FCX
# Processing ticker 153: FDS
# Processing ticker 154: FDX
# Processing ticker 155: FE
# Processing ticker 156: FFIV
# Processing ticker 157: FI
# Processing ticker 158: FICO
# Processing ticker 159: FIS
# Processing ticker 160: FITB
# Processing ticker 161: FRT
# Processing ticker 162: FSLR
# Processing ticker 163: FTNT
# Processing ticker 164: GD
# Processing ticker 165: GE
# Processing ticker 166: GEN
# Processing ticker 167: GILD
# Processing ticker 168: GIS
# Processing ticker 169: GL
# Processing ticker 170: GLW
# Processing ticker 171: GOOGL
# Processing ticker 172: GPC
# Processing ticker 173: GPN
# Processing ticker 174: GRMN
# Processing ticker 175: GS
# Processing ticker 176: GWW
# Processing ticker 177: HAL
# Processing ticker 178: HAS
# Processing ticker 179: HBAN
# Processing ticker 180: HD
# Processing ticker 181: HIG
# Processing ticker 182: HOLX
# Processing ticker 183: HON
# Processing ticker 184: HPQ
# Processing ticker 185: HRL
# Processing ticker 186: HSIC
# Processing ticker 187: HST
# Processing ticker 188: HSY
# Processing ticker 189: HUBB
# Processing ticker 190: HUM
# Processing ticker 191: IBM
# Processing ticker 192: ICE
# Processing ticker 193: IDXX
# Processing ticker 194: IEX
# Processing ticker 195: IFF
# Processing ticker 196: INCY
# Processing ticker 197: INTC
# Processing ticker 198: INTU
# Processing ticker 199: IP
# Processing ticker 200: IPG
# Processing ticker 201: IRM
# Processing ticker 202: ISRG
# Processing ticker 203: IT
# Processing ticker 204: ITW
# Processing ticker 205: IVZ
# Processing ticker 206: J
# Processing ticker 207: JBHT
# Processing ticker 208: JBL
# Processing ticker 209: JCI
# Processing ticker 210: JKHY
# Processing ticker 211: JNJ
# Processing ticker 212: JPM
# Processing ticker 213: K
# Processing ticker 214: KDP
# Processing ticker 215: KEY
# Processing ticker 216: KIM
# Processing ticker 217: KLAC
# Processing ticker 218: KMB
# Processing ticker 219: KMX
# Processing ticker 220: KO
# Processing ticker 221: KR
# Processing ticker 222: L
# Processing ticker 223: LDOS
# Processing ticker 224: LEN
# Processing ticker 225: LH
# Processing ticker 226: LHX
# Processing ticker 227: LII
# Processing ticker 228: LIN
# Processing ticker 229: LKQ
# Processing ticker 230: LLY
# Processing ticker 231: LMT
# Processing ticker 232: LNT
# Processing ticker 233: LOW
# Processing ticker 234: LRCX
# Processing ticker 235: LULU
# Processing ticker 236: LUV
# Processing ticker 237: LVS
# Processing ticker 238: LYV
# Processing ticker 239: MA
# Processing ticker 240: MAA
# Processing ticker 241: MAR
# Processing ticker 242: MAS
# Processing ticker 243: MCD
# Processing ticker 244: MCHP
# Processing ticker 245: MCK
# Processing ticker 246: MCO
# Processing ticker 247: MDLZ
# Processing ticker 248: MDT
# Processing ticker 249: MET
# Processing ticker 250: MGM
# Processing ticker 251: MHK
# Processing ticker 252: MKC
# Processing ticker 253: MKTX
# Processing ticker 254: MLM
# Processing ticker 255: MMC
# Processing ticker 256: MMM
# Processing ticker 257: MNST
# Processing ticker 258: MO
# Processing ticker 259: MOH
# Processing ticker 260: MOS
# Processing ticker 261: MPWR
# Processing ticker 262: MRK
# Processing ticker 263: MS
# Processing ticker 264: MSCI
# Processing ticker 265: MSFT
# Processing ticker 266: MSI
# Processing ticker 267: MTB
# Processing ticker 268: MTCH
# Processing ticker 269: MTD
# Processing ticker 270: MU
# Processing ticker 271: NDAQ
# Processing ticker 272: NDSN
# Processing ticker 273: NEE
# Processing ticker 274: NEM
# Processing ticker 275: NFLX
# Processing ticker 276: NI
# Processing ticker 277: NKE
# Processing ticker 278: NOC
# Processing ticker 279: NRG
# Processing ticker 280: NSC
# Processing ticker 281: NTAP
# Processing ticker 282: NTRS
# Processing ticker 283: NUE
# Processing ticker 284: NVDA
# Processing ticker 285: NVR
# Processing ticker 286: O
# Processing ticker 287: ODFL
# Processing ticker 288: OKE
# Processing ticker 289: OMC
# Processing ticker 290: ON
# Processing ticker 291: ORCL
# Processing ticker 292: ORLY
# Processing ticker 293: OXY
# Processing ticker 294: PARA
# Processing ticker 295: PAYX
# Processing ticker 296: PCAR
# Processing ticker 297: PCG
# Processing ticker 298: PEG
# Processing ticker 299: PEP
# Processing ticker 300: PFE
# Processing ticker 301: PFG
# Processing ticker 302: PG
# Processing ticker 303: PGR
# Processing ticker 304: PH
# Processing ticker 305: PHM
# Processing ticker 306: PKG
# Processing ticker 307: PLD
# Processing ticker 308: PM
# Processing ticker 309: PNC
# Processing ticker 310: PNR
# Processing ticker 311: PNW
# Processing ticker 312: PODD
# Processing ticker 313: POOL
# Processing ticker 314: PPG
# Processing ticker 315: PPL
# Processing ticker 316: PRU
# Processing ticker 317: PSA
# Processing ticker 318: PTC
# Processing ticker 319: PWR
# Processing ticker 320: QCOM
# Processing ticker 321: RCL
# Processing ticker 322: REG
# Processing ticker 323: REGN
# Processing ticker 324: RF
# Processing ticker 325: RJF
# Processing ticker 326: RL
# Processing ticker 327: RMD
# Processing ticker 328: ROK
# Processing ticker 329: ROL
# Processing ticker 330: ROP
# Processing ticker 331: ROST
# Processing ticker 332: RSG
# Processing ticker 333: RTX
# Processing ticker 334: RVTY
# Processing ticker 335: SBAC
# Processing ticker 336: SBUX
# Processing ticker 337: SCHW
# Processing ticker 338: SHW
# Processing ticker 339: SJM
# Processing ticker 340: SLB
# Processing ticker 341: SMCI
# Processing ticker 342: SNA
# Processing ticker 343: SNPS
# Processing ticker 344: SO
# Processing ticker 345: SPG
# Processing ticker 346: SPGI
# Processing ticker 347: SRE
# Processing ticker 348: STE
# Processing ticker 349: STLD
# Processing ticker 350: STT
# Processing ticker 351: STX
# Processing ticker 352: STZ
# Processing ticker 353: SW
# Processing ticker 354: SWK
# Processing ticker 355: SWKS
# Processing ticker 356: SYK
# Processing ticker 357: SYY
# Processing ticker 358: T
# Processing ticker 359: TAP
# Processing ticker 360: TDG
# Processing ticker 361: TDY
# Processing ticker 362: TECH
# Processing ticker 363: TEL
# Processing ticker 364: TER
# Processing ticker 365: TFC
# Processing ticker 366: TGT
# Processing ticker 367: TJX
# Processing ticker 368: TKO
# Processing ticker 369: TMO
# Processing ticker 370: TMUS
# Processing ticker 371: TPL
# Processing ticker 372: TPR
# Processing ticker 373: TRMB
# Processing ticker 374: TROW
# Processing ticker 375: TRV
# Processing ticker 376: TSCO
# Processing ticker 377: TSN
# Processing ticker 378: TT
# Processing ticker 379: TTWO
# Processing ticker 380: TXN
# Processing ticker 381: TXT
# Processing ticker 382: TYL
# Processing ticker 383: UAL
# Processing ticker 384: UDR
# Processing ticker 385: UHS
# Processing ticker 386: ULTA
# Processing ticker 387: UNH
# Processing ticker 388: UNP
# Processing ticker 389: UPS
# Processing ticker 390: URI
# Processing ticker 391: USB
# Processing ticker 392: V
# Processing ticker 393: VLO
# Processing ticker 394: VMC
# Processing ticker 395: VRSK
# Processing ticker 396: VRSN
# Processing ticker 397: VRTX
# Processing ticker 398: VTR
# Processing ticker 399: VTRS
# Processing ticker 400: VZ
# Processing ticker 401: WAB
# Processing ticker 402: WAT
# Processing ticker 403: WBA
# Processing ticker 404: WBD
# Processing ticker 405: WDC
# Processing ticker 406: WEC
# Processing ticker 407: WELL
# Processing ticker 408: WFC
# Processing ticker 409: WM
# Processing ticker 410: WMB
# Processing ticker 411: WMT
# Processing ticker 412: WRB
# Processing ticker 413: WSM
# Processing ticker 414: WST
# Processing ticker 415: WTW
# Processing ticker 416: WY
# Processing ticker 417: WYNN
# Processing ticker 418: XEL
# Processing ticker 419: XOM
# Processing ticker 420: YUM
# Processing ticker 421: ZBH
# Processing ticker 422: ZBRA
